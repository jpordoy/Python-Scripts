# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, accuracy_score
from sklearn.ensemble import RandomForestClassifier
#KERAS
from keras.models  import Sequential, K
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam, SGD, RMSprop
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

#end of imports

#Get the datasets
df = pd.read_csv('Dataset/EpilepsyTrain.csv')

df.info()
df.mean()
df.head(10)
df.hist()




#LOGISTICAL REGRESSION
#Building a Logistic Regression model
from sklearn.model_selection import train_test_split

#Split the epileptic data: 70%training||30% testing using the SKLearn train_test_Split
x_train, x_test,y_train,y_test = train_test_split(df.drop('Outcome',axis=1),df['Outcome'],
                                                  test_size=0.30,random_state=101)

#Training and Predicting
#Import the Logisitcal Regression Library from SKLearn
from sklearn.linear_model import LogisticRegression

#create instance of logistical regression model called logmodel
logmodel=LogisticRegression()
#pass the data to the logmodel
logmodel.fit(x_train,y_train)

#make predictions with model on unseen test data
predictions = logmodel.predict(x_test)


#Evaluation of performance metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

print("Accuracy score for Logistical Regression Model is:",accuracy_score(y_test, predictions)*100)
print("\nLogisitcal Regression Classification Report\n")
print(classification_report(y_test,predictions))

#End of logistical Regression Model


#train.groupby('Outcome').mean()

from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap

cm=confusion_matrix(y_test, predictions)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("CONFUSION MATRIX FOR LOGISTICAL REGERSSION MODEL")
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="YlGnBu")
plt.savefig('lrcm.png')



cm=confusion_matrix(y_test, predictions)
fig1 = plt.gcf()
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.tab20_r)
classNames = ['Negative','Positive']
plt.title("CONFUSION MATRIX FOR LOGISTICAL REGERSSION MODEL")
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()
plt.draw()
fig1.savefig('tessstttyyy.png', dpi=100)



from sklearn.model_selection import cross_val_score
from sklearn import metrics

auc_roc=metrics.roc_auc_score(y_test, predictions)
auc_roc

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic for Logistical Regression Model')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.grid(True)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('lrroc.png')


y_pred_prob=logmodel.predict_proba(x_test)[:,:]
y_pred_prob_df=pd.DataFrame(data=y_pred_prob, columns=['Prob of no Seizure (0)','Prob of Seizure (1)'])
y_pred_prob_df.head()


#DECISION TREE WITH GINI INDEX

#first 3 attributes are used for the x-axis
X = df.values[:, 0:3]
#attributes after number 3 are used for the y-axis
Y = df.values[:,3]

#import Accuracy Score to guage performance
from sklearn.metrics import accuracy_score

#Split the dataset using 70% for training and 30% for testing
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3, random_state = 100)

#implement a depth of 5, with a minimum of 5 leaf nodes and a random state of 100
dt_clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=5, min_samples_leaf=5)

#pass the training data to the decision tree
dt_clf_gini.fit(X_train, y_train)

#make prediction using unseen test data
y_pred_gini = dt_clf_gini.predict(X_test)

#methods used to show the performance metrics of the model
print ("\nAccuracy Score for Desicion Tree Model using Gini Index is ", accuracy_score(y_test,y_pred_gini)*100 )
print("\nDesicion Tree  Classification Report\n")
print(classification_report(y_test,predictions))

y_pred_prob=dt_clf_gini.predict_proba(X_test)[:,:]
y_pred_prob_df=pd.DataFrame(data=y_pred_prob, columns=['Prob of no seizure (0)','Prob of Seizure (1)'])
y_pred_prob_df.head(10)

df.describe()

#imports for confusion matrix
from sklearn.metrics import confusion_matrix

#pass test data and model variable to fill parameters of confusion matrix
cm=confusion_matrix(y_test, y_pred_gini)

#create a confusion matrix to visually display the postive and negative prediction rate
fig1 = plt.gcf()
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.tab20_r)
classNames = ['Negative','Positive']
plt.title("CONFUSION MATRIX FOR GINI DECISION TREE")
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()
plt.draw()
fig1.savefig('dt1.png', dpi=100)





from sklearn.model_selection import cross_val_score
from sklearn import metrics



auc_roc=metrics.roc_auc_score(y_test, y_pred_gini)
auc_roc

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_gini)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic for Decision Tree with Gini Index')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.grid(True)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rates')
plt.savefig('drroc.png')



#RANDOM FOREST

X = df.iloc[:, :-1].values

#y-axis uses the variable outcome as its target variable
y = df["Outcome"].values

#splitt the training data using 70% for training and 30% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11111)

#shows percentage of seizures compared to non seizures
np.mean(y), np.mean(1-y)


## Train the RF Model
rf_model = RandomForestClassifier(n_estimators=200)
rf_model.fit(X_train, y_train)

# Make predictions on the test set - both "hard" predictions, and the scores (percent of trees voting yes)
y_pred_class_rf = rf_model.predict(X_test)
y_pred_prob_rf = rf_model.predict_proba(X_test)


#list the performance metrics the model emanates
print('\nAccuracy Score for Random Forest Model is {:.3f}'.format(accuracy_score(y_test,y_pred_class_rf)*100))
print('\nRandom Forest roc-auc measure is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_rf[:,1])))
print("\nRandom Forest  Classification Report\n")
print(classification_report(y_test,y_pred_class_rf))



#create a confusion matrix to visually display the postive and negative prediction rate
cmrf=confusion_matrix(y_test,y_pred_class_rf)
conf_matrixrf=pd.DataFrame(data=cmrf,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("CONFUSION MATRIX FOR RANDOM FOREST")
sns.heatmap(conf_matrixrf, annot=True,fmt='d',cmap="YlGnBu")
plt.savefig('cmrf.png')

#create a confusion matrix to visually display the postive and negative prediction rate
cmrf=confusion_matrix(y_test,y_pred_class_rf)
fig1 = plt.gcf()

plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.tab20_r)
classNames = ['Negative','Positive']
plt.title("CONFUSION MATRIX FOR RANDOM FOREST")
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()
plt.draw()
fig1.savefig('rf1.png', dpi=100)


from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_class_rf)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic for Random Forest Model')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.grid(True)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rates')
plt.show()
plt.savefig('drroc.png')



#NEURAL NETWORK

## normalize the data

normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# 1 hidden layer, 12 hidden nodes, sigmoid activation

model_1 = Sequential([
    Dense(12, input_shape=(3,), activation="relu"),
    Dense(1, activation="sigmoid")
])

print("\n************Start of Nerual Netwrok Summary*********")
model_1.summary()

# Fit(Train) the Model
model_1.compile(SGD(lr = .003), "binary_crossentropy", metrics=["accuracy"])
run_hist_1 = model_1.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=200)

#  One is a hard decision, the other is a probabilitistic score.
y_pred_class_nn_1 = model_1.predict_classes(X_test_norm)
y_pred_prob_nn_1 = model_1.predict(X_test_norm)

y_pred_class_nn_1[:10]
y_pred_prob_nn_1[:10]

# Print model performance and plot the roc curve
print('\n')
print('\nAccuracy Score for Nerual Network is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)*100))
print('\nNerual Network roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))
print("\nNerual Network Classification Report\n")
print(classification_report(y_test,y_pred_class_rf))

#create a confusion matrix
cmrf=confusion_matrix(y_test,y_pred_class_nn_1)
fig1 = plt.gcf()
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.tab20_r)
classNames = ['Negative','Positive']
plt.title("CONFUSION MATRIX FOR NEURAL NETWORK")
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()
plt.draw()
fig1.savefig('nn1cm.png', dpi=100)

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred_prob_nn_1)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic for Nerual Network')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.grid(True)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rates')
plt.savefig('nnroc.png')




run_hist_1.history.keys()
fig, ax = plt.subplots()
ax.plot(run_hist_1.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.legend()


## Note that when we call "fit" again, it picks up where it left off
run_hist_1b = model_1.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=2000)




n = len(run_hist_1.history["loss"])
m = len(run_hist_1b.history['loss'])
fig, ax = plt.subplots(figsize=(16, 8))

ax.plot(range(n), run_hist_1.history["loss"],'r', marker='.', label="Train Loss - Run 1")
ax.plot(range(n, n+m), run_hist_1b.history["loss"], 'hotpink', marker='.', label="Train Loss - Run 3")

ax.plot(range(n), run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss - Run 1")
ax.plot(range(n, n+m), run_hist_1b.history["val_loss"], 'LightSkyBlue', marker='.',  label="Validation Loss - Run 3")
plt.ylabel('Loss')
plt.xlabel('Epoch')
ax.legend()


# Print model performance and plot the roc curve
print('\n')
print('\nAccuracy Score for Nerual Network is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)*100))
print('\nNerual Network roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))
print("\n")
print("\nNerual Network Classification Report\n")
print(classification_report(y_test,y_pred_class_rf))


#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.savefig('corr.png')



# prepare configuration for cross validation test harness
seed = 7

# prepare models
models = []
models.append(('LogisticRegression', LogisticRegression()))
models.append(('RandomForest', RandomForestClassifier()))
models.append(('DecisionTree', DecisionTreeClassifier()))
# evaluate each model in turn

results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)


    
# boxplot algorithm comparison
#mean and standard deviation
fig = plt.gcf()
fig = plt.figure()
fig = plt.figure(figsize=(10,7))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
plt.draw()
fig.savefig('boxplot.png', dpi=100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 4 columns):
# Hours_Slept     71 non-null float64
# Stress_Level    71 non-null float64
# Exercise        71 non-null int64
# Outcome         71 non-null int64
# dtypes: float64(2), int64(2)
# memory usage: 2.3 KB
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\jamie\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# Accuracy score for Logistical Regression Model is: 86.36363636363636
#
# Logisitcal Regression Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90        16
#            1       0.71      0.83      0.77         6
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.85      0.84        22
# weighted avg       0.87      0.86      0.87        22
# Accuracy Score for Desicion Tree Model using Gini Index is  86.36363636363636
#
# Desicion Tree  Classification Report
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.14      0.50      0.22         2
#
#     accuracy                           0.68        22
#    macro avg       0.54      0.60      0.51        22
# weighted avg       0.86      0.68      0.75        22
# Accuracy Score for Random Forest Model is 81.818
#
# Random Forest roc-auc measure is 0.853
#
# Random Forest  Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89        17
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.82        22
#    macro avg       0.75      0.67      0.69        22
# weighted avg       0.80      0.82      0.80        22
# WARNING: Logging before flag parsing goes to stderr.
# W1029 10:54:23.359188 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1029 10:54:23.425092 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1029 10:54:23.469165 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1029 10:54:23.519029 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1029 10:54:23.524000 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1029 10:54:23.531000 13036 deprecation.py:323] From C:\Users\jamie\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ************Start of Nerual Netwrok Summary*********
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12)                48
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# W1029 10:54:23.719150 13036 deprecation_wrapper.py:119] From C:\Users\jamie\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 49 samples, validate on 22 samples
# Epoch 1/200
# 49/49 [==============================] - 0s 8ms/step - loss: 1.1303 - acc: 0.2245 - val_loss: 1.1237 - val_acc: 0.2273
# Epoch 2/200
# 49/49 [==============================] - 0s 53us/step - loss: 1.1213 - acc: 0.2245 - val_loss: 1.1144 - val_acc: 0.2273
# Epoch 3/200
# 49/49 [==============================] - 0s 82us/step - loss: 1.1123 - acc: 0.2245 - val_loss: 1.1053 - val_acc: 0.2273
# Epoch 4/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.1034 - acc: 0.2245 - val_loss: 1.0965 - val_acc: 0.2273
# Epoch 5/200
# 49/49 [==============================] - 0s 62us/step - loss: 1.0946 - acc: 0.2245 - val_loss: 1.0874 - val_acc: 0.2273
# Epoch 6/200
# 49/49 [==============================] - 0s 61us/step - loss: 1.0858 - acc: 0.2245 - val_loss: 1.0788 - val_acc: 0.2273
# Epoch 7/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.0774 - acc: 0.2245 - val_loss: 1.0704 - val_acc: 0.2273
# Epoch 8/200
# 49/49 [==============================] - 0s 61us/step - loss: 1.0691 - acc: 0.2245 - val_loss: 1.0619 - val_acc: 0.2273
# Epoch 9/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.0606 - acc: 0.2245 - val_loss: 1.0534 - val_acc: 0.2273
# Epoch 10/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.0523 - acc: 0.2245 - val_loss: 1.0452 - val_acc: 0.2273
# Epoch 11/200
# 49/49 [==============================] - 0s 40us/step - loss: 1.0441 - acc: 0.2245 - val_loss: 1.0367 - val_acc: 0.2273
# Epoch 12/200
# 49/49 [==============================] - 0s 41us/step - loss: 1.0359 - acc: 0.2245 - val_loss: 1.0288 - val_acc: 0.2273
# Epoch 13/200
# 49/49 [==============================] - 0s 40us/step - loss: 1.0281 - acc: 0.2245 - val_loss: 1.0211 - val_acc: 0.2273
# Epoch 14/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.0203 - acc: 0.2245 - val_loss: 1.0131 - val_acc: 0.2273
# Epoch 15/200
# 49/49 [==============================] - 0s 81us/step - loss: 1.0125 - acc: 0.2245 - val_loss: 1.0055 - val_acc: 0.2273
# Epoch 16/200
# 49/49 [==============================] - 0s 102us/step - loss: 1.0049 - acc: 0.2245 - val_loss: 0.9977 - val_acc: 0.2273
# Epoch 17/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.9974 - acc: 0.2245 - val_loss: 0.9907 - val_acc: 0.2273
# Epoch 18/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.9901 - acc: 0.2449 - val_loss: 0.9829 - val_acc: 0.2273
# Epoch 19/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.9823 - acc: 0.2449 - val_loss: 0.9753 - val_acc: 0.2273
# Epoch 20/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.9752 - acc: 0.2449 - val_loss: 0.9688 - val_acc: 0.2273
# Epoch 21/200
# 49/49 [==============================] - 0s 62us/step - loss: 0.9683 - acc: 0.2449 - val_loss: 0.9617 - val_acc: 0.2273
# Epoch 22/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.9612 - acc: 0.2449 - val_loss: 0.9542 - val_acc: 0.2273
# Epoch 23/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.9538 - acc: 0.2449 - val_loss: 0.9473 - val_acc: 0.2273
# Epoch 24/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.9468 - acc: 0.2449 - val_loss: 0.9404 - val_acc: 0.2273
# Epoch 25/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.9399 - acc: 0.2449 - val_loss: 0.9336 - val_acc: 0.2273
# Epoch 26/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.9330 - acc: 0.2449 - val_loss: 0.9269 - val_acc: 0.2273
# Epoch 27/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.9262 - acc: 0.2449 - val_loss: 0.9202 - val_acc: 0.2273
# Epoch 28/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.9196 - acc: 0.2449 - val_loss: 0.9138 - val_acc: 0.2273
# Epoch 29/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.9130 - acc: 0.2449 - val_loss: 0.9073 - val_acc: 0.2273
# Epoch 30/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.9064 - acc: 0.2449 - val_loss: 0.9008 - val_acc: 0.2273
# Epoch 31/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.8999 - acc: 0.2449 - val_loss: 0.8947 - val_acc: 0.2273
# Epoch 32/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8939 - acc: 0.2449 - val_loss: 0.8889 - val_acc: 0.2273
# Epoch 33/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8878 - acc: 0.2449 - val_loss: 0.8827 - val_acc: 0.2273
# Epoch 34/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8815 - acc: 0.2449 - val_loss: 0.8769 - val_acc: 0.2727
# Epoch 35/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.8755 - acc: 0.2449 - val_loss: 0.8708 - val_acc: 0.2727
# Epoch 36/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8695 - acc: 0.2449 - val_loss: 0.8652 - val_acc: 0.2727
# Epoch 37/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.8636 - acc: 0.2449 - val_loss: 0.8594 - val_acc: 0.2727
# Epoch 38/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.8577 - acc: 0.2449 - val_loss: 0.8537 - val_acc: 0.2727
# Epoch 39/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.8520 - acc: 0.2449 - val_loss: 0.8484 - val_acc: 0.2727
# Epoch 40/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.8464 - acc: 0.2449 - val_loss: 0.8429 - val_acc: 0.2727
# Epoch 41/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.8408 - acc: 0.2449 - val_loss: 0.8374 - val_acc: 0.2727
# Epoch 42/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.8350 - acc: 0.2449 - val_loss: 0.8318 - val_acc: 0.2727
# Epoch 43/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.8295 - acc: 0.2449 - val_loss: 0.8269 - val_acc: 0.2727
# Epoch 44/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8242 - acc: 0.2449 - val_loss: 0.8214 - val_acc: 0.2727
# Epoch 45/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.8187 - acc: 0.2653 - val_loss: 0.8162 - val_acc: 0.2727
# Epoch 46/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.8133 - acc: 0.3061 - val_loss: 0.8112 - val_acc: 0.2727
# Epoch 47/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.8083 - acc: 0.3469 - val_loss: 0.8065 - val_acc: 0.2727
# Epoch 48/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.8033 - acc: 0.4286 - val_loss: 0.8015 - val_acc: 0.2727
# Epoch 49/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7982 - acc: 0.5102 - val_loss: 0.7966 - val_acc: 0.3182
# Epoch 50/200
# 49/49 [==============================] - 0s 82us/step - loss: 0.7934 - acc: 0.5102 - val_loss: 0.7922 - val_acc: 0.3182
# Epoch 51/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7887 - acc: 0.5102 - val_loss: 0.7877 - val_acc: 0.3182
# Epoch 52/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.7839 - acc: 0.5102 - val_loss: 0.7830 - val_acc: 0.3182
# Epoch 53/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.7791 - acc: 0.5102 - val_loss: 0.7784 - val_acc: 0.3636
# Epoch 54/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7744 - acc: 0.5510 - val_loss: 0.7740 - val_acc: 0.3636
# Epoch 55/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7699 - acc: 0.5510 - val_loss: 0.7699 - val_acc: 0.3636
# Epoch 56/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7654 - acc: 0.5510 - val_loss: 0.7655 - val_acc: 0.3636
# Epoch 57/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7608 - acc: 0.5510 - val_loss: 0.7611 - val_acc: 0.3636
# Epoch 58/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7562 - acc: 0.5510 - val_loss: 0.7569 - val_acc: 0.3636
# Epoch 59/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.7517 - acc: 0.5510 - val_loss: 0.7525 - val_acc: 0.4545
# Epoch 60/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7472 - acc: 0.5918 - val_loss: 0.7484 - val_acc: 0.4545
# Epoch 61/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7429 - acc: 0.6122 - val_loss: 0.7443 - val_acc: 0.4545
# Epoch 62/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7386 - acc: 0.6122 - val_loss: 0.7401 - val_acc: 0.4545
# Epoch 63/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7343 - acc: 0.6122 - val_loss: 0.7363 - val_acc: 0.4545
# Epoch 64/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7303 - acc: 0.6122 - val_loss: 0.7325 - val_acc: 0.4545
# Epoch 65/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7263 - acc: 0.6122 - val_loss: 0.7285 - val_acc: 0.5000
# Epoch 66/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7221 - acc: 0.6122 - val_loss: 0.7247 - val_acc: 0.5000
# Epoch 67/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7180 - acc: 0.6122 - val_loss: 0.7208 - val_acc: 0.5000
# Epoch 68/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.7138 - acc: 0.6327 - val_loss: 0.7169 - val_acc: 0.5455
# Epoch 69/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.7097 - acc: 0.6939 - val_loss: 0.7129 - val_acc: 0.5455
# Epoch 70/200
# 49/49 [==============================] - 0s 78us/step - loss: 0.7056 - acc: 0.6939 - val_loss: 0.7092 - val_acc: 0.5455
# Epoch 71/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.7017 - acc: 0.6939 - val_loss: 0.7055 - val_acc: 0.5455
# Epoch 72/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.6978 - acc: 0.7347 - val_loss: 0.7021 - val_acc: 0.5455
# Epoch 73/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.6940 - acc: 0.7347 - val_loss: 0.6985 - val_acc: 0.5455
# Epoch 74/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6903 - acc: 0.7347 - val_loss: 0.6951 - val_acc: 0.5455
# Epoch 75/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6866 - acc: 0.7347 - val_loss: 0.6912 - val_acc: 0.6364
# Epoch 76/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6825 - acc: 0.7347 - val_loss: 0.6879 - val_acc: 0.6364
# Epoch 77/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6790 - acc: 0.7347 - val_loss: 0.6846 - val_acc: 0.5909
# Epoch 78/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6755 - acc: 0.7347 - val_loss: 0.6813 - val_acc: 0.6364
# Epoch 79/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6719 - acc: 0.7551 - val_loss: 0.6779 - val_acc: 0.6364
# Epoch 80/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6683 - acc: 0.7551 - val_loss: 0.6745 - val_acc: 0.6364
# Epoch 81/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6648 - acc: 0.7551 - val_loss: 0.6711 - val_acc: 0.6364
# Epoch 82/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6612 - acc: 0.7551 - val_loss: 0.6679 - val_acc: 0.6364
# Epoch 83/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6577 - acc: 0.7551 - val_loss: 0.6647 - val_acc: 0.6364
# Epoch 84/200
# 49/49 [==============================] - 0s 62us/step - loss: 0.6543 - acc: 0.7551 - val_loss: 0.6615 - val_acc: 0.6818
# Epoch 85/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6510 - acc: 0.7755 - val_loss: 0.6584 - val_acc: 0.6818
# Epoch 86/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6476 - acc: 0.7755 - val_loss: 0.6551 - val_acc: 0.6818
# Epoch 87/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.6441 - acc: 0.7755 - val_loss: 0.6519 - val_acc: 0.6818
# Epoch 88/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6407 - acc: 0.7755 - val_loss: 0.6489 - val_acc: 0.6818
# Epoch 89/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6375 - acc: 0.7755 - val_loss: 0.6458 - val_acc: 0.6818
# Epoch 90/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6343 - acc: 0.7755 - val_loss: 0.6429 - val_acc: 0.6818
# Epoch 91/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6312 - acc: 0.7755 - val_loss: 0.6400 - val_acc: 0.6818
# Epoch 92/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.6280 - acc: 0.7755 - val_loss: 0.6370 - val_acc: 0.6818
# Epoch 93/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.6248 - acc: 0.7755 - val_loss: 0.6341 - val_acc: 0.6818
# Epoch 94/200
# 49/49 [==============================] - 0s 62us/step - loss: 0.6217 - acc: 0.7755 - val_loss: 0.6314 - val_acc: 0.6818
# Epoch 95/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.6188 - acc: 0.7755 - val_loss: 0.6287 - val_acc: 0.6818
# Epoch 96/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.6159 - acc: 0.7755 - val_loss: 0.6261 - val_acc: 0.6818
# Epoch 97/200
# 49/49 [==============================] - 0s 82us/step - loss: 0.6130 - acc: 0.7755 - val_loss: 0.6232 - val_acc: 0.6818
# Epoch 98/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6099 - acc: 0.7755 - val_loss: 0.6205 - val_acc: 0.6818
# Epoch 99/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.6070 - acc: 0.7755 - val_loss: 0.6180 - val_acc: 0.6818
# Epoch 100/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.6042 - acc: 0.7755 - val_loss: 0.6153 - val_acc: 0.6818
# Epoch 101/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.6012 - acc: 0.7755 - val_loss: 0.6127 - val_acc: 0.6818
# Epoch 102/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.5985 - acc: 0.7755 - val_loss: 0.6104 - val_acc: 0.6818
# Epoch 103/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.5958 - acc: 0.7755 - val_loss: 0.6079 - val_acc: 0.6818
# Epoch 104/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.5931 - acc: 0.7755 - val_loss: 0.6053 - val_acc: 0.6818
# Epoch 105/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.5902 - acc: 0.7755 - val_loss: 0.6027 - val_acc: 0.6818
# Epoch 106/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5874 - acc: 0.7755 - val_loss: 0.6003 - val_acc: 0.8182
# Epoch 107/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.5847 - acc: 0.8163 - val_loss: 0.5977 - val_acc: 0.8182
# Epoch 108/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.5820 - acc: 0.8163 - val_loss: 0.5954 - val_acc: 0.8182
# Epoch 109/200
# 49/49 [==============================] - 0s 62us/step - loss: 0.5793 - acc: 0.8163 - val_loss: 0.5930 - val_acc: 0.8182
# Epoch 110/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.5766 - acc: 0.8163 - val_loss: 0.5906 - val_acc: 0.8182
# Epoch 111/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.5740 - acc: 0.8163 - val_loss: 0.5883 - val_acc: 0.8182
# Epoch 112/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5714 - acc: 0.8163 - val_loss: 0.5860 - val_acc: 0.8182
# Epoch 113/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5688 - acc: 0.8571 - val_loss: 0.5837 - val_acc: 0.8182
# Epoch 114/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5664 - acc: 0.8571 - val_loss: 0.5816 - val_acc: 0.8182
# Epoch 115/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5640 - acc: 0.8571 - val_loss: 0.5794 - val_acc: 0.8182
# Epoch 116/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.5616 - acc: 0.8776 - val_loss: 0.5774 - val_acc: 0.8182
# Epoch 117/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5592 - acc: 0.8776 - val_loss: 0.5753 - val_acc: 0.8182
# Epoch 118/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5569 - acc: 0.8776 - val_loss: 0.5731 - val_acc: 0.8182
# Epoch 119/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5544 - acc: 0.8776 - val_loss: 0.5711 - val_acc: 0.8182
# Epoch 120/200
# 49/49 [==============================] - 0s 54us/step - loss: 0.5521 - acc: 0.8776 - val_loss: 0.5691 - val_acc: 0.8182
# Epoch 121/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5498 - acc: 0.8776 - val_loss: 0.5669 - val_acc: 0.8182
# Epoch 122/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5473 - acc: 0.8776 - val_loss: 0.5649 - val_acc: 0.8182
# Epoch 123/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5450 - acc: 0.8776 - val_loss: 0.5629 - val_acc: 0.8182
# Epoch 124/200
# 49/49 [==============================] - ETA: 0s - loss: 0.5837 - acc: 0.843 - 0s 121us/step - loss: 0.5429 - acc: 0.8776 - val_loss: 0.5611 - val_acc: 0.8182
# Epoch 125/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5406 - acc: 0.8776 - val_loss: 0.5592 - val_acc: 0.8182
# Epoch 126/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.5384 - acc: 0.8776 - val_loss: 0.5573 - val_acc: 0.8182
# Epoch 127/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5361 - acc: 0.8776 - val_loss: 0.5553 - val_acc: 0.8182
# Epoch 128/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5339 - acc: 0.8776 - val_loss: 0.5535 - val_acc: 0.8182
# Epoch 129/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5318 - acc: 0.8776 - val_loss: 0.5517 - val_acc: 0.8182
# Epoch 130/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5296 - acc: 0.8776 - val_loss: 0.5499 - val_acc: 0.8182
# Epoch 131/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.5275 - acc: 0.8776 - val_loss: 0.5479 - val_acc: 0.8182
# Epoch 132/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5252 - acc: 0.8776 - val_loss: 0.5461 - val_acc: 0.8182
# Epoch 133/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.5230 - acc: 0.8776 - val_loss: 0.5442 - val_acc: 0.8182
# Epoch 134/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5207 - acc: 0.8776 - val_loss: 0.5425 - val_acc: 0.8182
# Epoch 135/200
# 49/49 [==============================] - 0s 62us/step - loss: 0.5187 - acc: 0.8776 - val_loss: 0.5407 - val_acc: 0.8182
# Epoch 136/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5165 - acc: 0.8776 - val_loss: 0.5390 - val_acc: 0.8182
# Epoch 137/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5144 - acc: 0.8776 - val_loss: 0.5373 - val_acc: 0.8182
# Epoch 138/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5123 - acc: 0.8776 - val_loss: 0.5356 - val_acc: 0.8182
# Epoch 139/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5103 - acc: 0.8776 - val_loss: 0.5339 - val_acc: 0.8182
# Epoch 140/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.5083 - acc: 0.8776 - val_loss: 0.5323 - val_acc: 0.8182
# Epoch 141/200
# 49/49 [==============================] - 0s 82us/step - loss: 0.5063 - acc: 0.8980 - val_loss: 0.5307 - val_acc: 0.8182
# Epoch 142/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5043 - acc: 0.8980 - val_loss: 0.5291 - val_acc: 0.8182
# Epoch 143/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.5023 - acc: 0.8980 - val_loss: 0.5275 - val_acc: 0.8182
# Epoch 144/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.5004 - acc: 0.8980 - val_loss: 0.5259 - val_acc: 0.8182
# Epoch 145/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4985 - acc: 0.8980 - val_loss: 0.5243 - val_acc: 0.8182
# Epoch 146/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4965 - acc: 0.8980 - val_loss: 0.5227 - val_acc: 0.8182
# Epoch 147/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.4946 - acc: 0.8980 - val_loss: 0.5212 - val_acc: 0.8182
# Epoch 148/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.4928 - acc: 0.8980 - val_loss: 0.5198 - val_acc: 0.8182
# Epoch 149/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4910 - acc: 0.8980 - val_loss: 0.5184 - val_acc: 0.8182
# Epoch 150/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4892 - acc: 0.8980 - val_loss: 0.5169 - val_acc: 0.8182
# Epoch 151/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4873 - acc: 0.8980 - val_loss: 0.5154 - val_acc: 0.8182
# Epoch 152/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.4855 - acc: 0.8980 - val_loss: 0.5140 - val_acc: 0.8182
# Epoch 153/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4837 - acc: 0.8980 - val_loss: 0.5125 - val_acc: 0.8182
# Epoch 154/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4820 - acc: 0.8980 - val_loss: 0.5112 - val_acc: 0.8182
# Epoch 155/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4802 - acc: 0.8980 - val_loss: 0.5099 - val_acc: 0.8182
# Epoch 156/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4785 - acc: 0.8980 - val_loss: 0.5086 - val_acc: 0.8182
# Epoch 157/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.4769 - acc: 0.8980 - val_loss: 0.5071 - val_acc: 0.8182
# Epoch 158/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.4751 - acc: 0.8980 - val_loss: 0.5058 - val_acc: 0.8182
# Epoch 159/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4735 - acc: 0.8980 - val_loss: 0.5046 - val_acc: 0.8182
# Epoch 160/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4718 - acc: 0.8980 - val_loss: 0.5032 - val_acc: 0.8182
# Epoch 161/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.4701 - acc: 0.8980 - val_loss: 0.5020 - val_acc: 0.8182
# Epoch 162/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4684 - acc: 0.8980 - val_loss: 0.5007 - val_acc: 0.8182
# Epoch 163/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.4668 - acc: 0.8980 - val_loss: 0.4994 - val_acc: 0.8182
# Epoch 164/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4652 - acc: 0.9184 - val_loss: 0.4982 - val_acc: 0.8182
# Epoch 165/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4636 - acc: 0.9184 - val_loss: 0.4970 - val_acc: 0.8182
# Epoch 166/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4620 - acc: 0.9184 - val_loss: 0.4958 - val_acc: 0.8182
# Epoch 167/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4604 - acc: 0.9184 - val_loss: 0.4945 - val_acc: 0.8182
# Epoch 168/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.4588 - acc: 0.9184 - val_loss: 0.4933 - val_acc: 0.8182
# Epoch 169/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4572 - acc: 0.9184 - val_loss: 0.4921 - val_acc: 0.8182
# Epoch 170/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4557 - acc: 0.9184 - val_loss: 0.4910 - val_acc: 0.8182
# Epoch 171/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.4543 - acc: 0.9184 - val_loss: 0.4898 - val_acc: 0.8182
# Epoch 172/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4527 - acc: 0.9184 - val_loss: 0.4887 - val_acc: 0.8182
# Epoch 173/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4512 - acc: 0.9184 - val_loss: 0.4875 - val_acc: 0.8182
# Epoch 174/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4498 - acc: 0.9184 - val_loss: 0.4864 - val_acc: 0.8182
# Epoch 175/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.4482 - acc: 0.9184 - val_loss: 0.4852 - val_acc: 0.8182
# Epoch 176/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4467 - acc: 0.9184 - val_loss: 0.4841 - val_acc: 0.8182
# Epoch 177/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4452 - acc: 0.9184 - val_loss: 0.4830 - val_acc: 0.8182
# Epoch 178/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.4437 - acc: 0.9184 - val_loss: 0.4819 - val_acc: 0.8182
# Epoch 179/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4423 - acc: 0.9184 - val_loss: 0.4809 - val_acc: 0.8182
# Epoch 180/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.4409 - acc: 0.9184 - val_loss: 0.4798 - val_acc: 0.8182
# Epoch 181/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4395 - acc: 0.9184 - val_loss: 0.4788 - val_acc: 0.8182
# Epoch 182/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4381 - acc: 0.9184 - val_loss: 0.4776 - val_acc: 0.8182
# Epoch 183/200
# 49/49 [==============================] - 0s 122us/step - loss: 0.4365 - acc: 0.9184 - val_loss: 0.4766 - val_acc: 0.8636
# Epoch 184/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4352 - acc: 0.9184 - val_loss: 0.4756 - val_acc: 0.8636
# Epoch 185/200
# 49/49 [==============================] - 0s 41us/step - loss: 0.4338 - acc: 0.9184 - val_loss: 0.4746 - val_acc: 0.8636
# Epoch 186/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4325 - acc: 0.9184 - val_loss: 0.4737 - val_acc: 0.8636
# Epoch 187/200
# 49/49 [==============================] - 0s 58us/step - loss: 0.4312 - acc: 0.9184 - val_loss: 0.4727 - val_acc: 0.8636
# Epoch 188/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4298 - acc: 0.9184 - val_loss: 0.4717 - val_acc: 0.8636
# Epoch 189/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4284 - acc: 0.9184 - val_loss: 0.4707 - val_acc: 0.8636
# Epoch 190/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4271 - acc: 0.9184 - val_loss: 0.4697 - val_acc: 0.8636
# Epoch 191/200
# 49/49 [==============================] - 0s 81us/step - loss: 0.4257 - acc: 0.9184 - val_loss: 0.4687 - val_acc: 0.8636
# Epoch 192/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.4244 - acc: 0.9184 - val_loss: 0.4678 - val_acc: 0.8636
# Epoch 193/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4232 - acc: 0.9184 - val_loss: 0.4668 - val_acc: 0.8636
# Epoch 194/200
# 49/49 [==============================] - 0s 102us/step - loss: 0.4218 - acc: 0.9184 - val_loss: 0.4659 - val_acc: 0.8636
# Epoch 195/200
# 49/49 [==============================] - 0s 60us/step - loss: 0.4205 - acc: 0.9184 - val_loss: 0.4650 - val_acc: 0.8636
# Epoch 196/200
# 49/49 [==============================] - 0s 40us/step - loss: 0.4192 - acc: 0.9184 - val_loss: 0.4641 - val_acc: 0.8636
# Epoch 197/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4180 - acc: 0.9184 - val_loss: 0.4632 - val_acc: 0.8636
# Epoch 198/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4168 - acc: 0.9184 - val_loss: 0.4624 - val_acc: 0.8636
# Epoch 199/200
# 49/49 [==============================] - 0s 76us/step - loss: 0.4155 - acc: 0.9184 - val_loss: 0.4615 - val_acc: 0.8636
# Epoch 200/200
# 49/49 [==============================] - 0s 61us/step - loss: 0.4143 - acc: 0.9184 - val_loss: 0.4607 - val_acc: 0.8636
#
#
#
# Accuracy Score for Nerual Network is 86.364
#
# Nerual Network roc-auc is 0.865
#
# Nerual Network Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89        17
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.82        22
#    macro avg       0.75      0.67      0.69        22
# weighted avg       0.80      0.82      0.80        22
# Train on 49 samples, validate on 22 samples
# Epoch 1/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4131 - acc: 0.9184 - val_loss: 0.4598 - val_acc: 0.8636
# Epoch 2/2000
# 49/49 [==============================] - 0s 86us/step - loss: 0.4119 - acc: 0.9184 - val_loss: 0.4590 - val_acc: 0.8636
# Epoch 3/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.4107 - acc: 0.9184 - val_loss: 0.4582 - val_acc: 0.8636
# Epoch 4/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4095 - acc: 0.9184 - val_loss: 0.4574 - val_acc: 0.8636
# Epoch 5/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4084 - acc: 0.9184 - val_loss: 0.4565 - val_acc: 0.8636
# Epoch 6/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.4072 - acc: 0.9184 - val_loss: 0.4558 - val_acc: 0.8636
# Epoch 7/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4061 - acc: 0.9184 - val_loss: 0.4550 - val_acc: 0.8636
# Epoch 8/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.4050 - acc: 0.9184 - val_loss: 0.4541 - val_acc: 0.8636
# Epoch 9/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4038 - acc: 0.9184 - val_loss: 0.4534 - val_acc: 0.8636
# Epoch 10/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.4027 - acc: 0.9184 - val_loss: 0.4527 - val_acc: 0.8636
# Epoch 11/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.4016 - acc: 0.9184 - val_loss: 0.4519 - val_acc: 0.8636
# Epoch 12/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.4005 - acc: 0.9184 - val_loss: 0.4511 - val_acc: 0.8636
# Epoch 13/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3993 - acc: 0.9184 - val_loss: 0.4503 - val_acc: 0.8636
# Epoch 14/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3983 - acc: 0.9184 - val_loss: 0.4496 - val_acc: 0.8636
# Epoch 15/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3972 - acc: 0.9184 - val_loss: 0.4489 - val_acc: 0.8636
# Epoch 16/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3962 - acc: 0.9184 - val_loss: 0.4482 - val_acc: 0.8636
# Epoch 17/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3951 - acc: 0.9184 - val_loss: 0.4475 - val_acc: 0.8636
# Epoch 18/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3941 - acc: 0.9184 - val_loss: 0.4468 - val_acc: 0.8636
# Epoch 19/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3930 - acc: 0.9184 - val_loss: 0.4460 - val_acc: 0.8636
# Epoch 20/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3919 - acc: 0.9184 - val_loss: 0.4453 - val_acc: 0.8636
# Epoch 21/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3909 - acc: 0.9184 - val_loss: 0.4446 - val_acc: 0.8636
# Epoch 22/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3898 - acc: 0.9184 - val_loss: 0.4439 - val_acc: 0.8636
# Epoch 23/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3887 - acc: 0.9184 - val_loss: 0.4432 - val_acc: 0.8636
# Epoch 24/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3877 - acc: 0.9184 - val_loss: 0.4426 - val_acc: 0.8636
# Epoch 25/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3867 - acc: 0.9184 - val_loss: 0.4419 - val_acc: 0.8636
# Epoch 26/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3856 - acc: 0.9184 - val_loss: 0.4413 - val_acc: 0.8636
# Epoch 27/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3847 - acc: 0.9184 - val_loss: 0.4406 - val_acc: 0.8636
# Epoch 28/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3837 - acc: 0.9184 - val_loss: 0.4400 - val_acc: 0.8636
# Epoch 29/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3827 - acc: 0.9184 - val_loss: 0.4393 - val_acc: 0.8636
# Epoch 30/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3818 - acc: 0.9184 - val_loss: 0.4387 - val_acc: 0.8636
# Epoch 31/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3808 - acc: 0.9184 - val_loss: 0.4381 - val_acc: 0.8636
# Epoch 32/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3798 - acc: 0.9184 - val_loss: 0.4374 - val_acc: 0.8636
# Epoch 33/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3789 - acc: 0.9184 - val_loss: 0.4368 - val_acc: 0.8636
# Epoch 34/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3780 - acc: 0.9184 - val_loss: 0.4362 - val_acc: 0.8636
# Epoch 35/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3770 - acc: 0.9184 - val_loss: 0.4356 - val_acc: 0.8636
# Epoch 36/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3761 - acc: 0.9184 - val_loss: 0.4350 - val_acc: 0.8636
# Epoch 37/2000
# 49/49 [==============================] - 0s 123us/step - loss: 0.3752 - acc: 0.9184 - val_loss: 0.4344 - val_acc: 0.8636
# Epoch 38/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3742 - acc: 0.9184 - val_loss: 0.4338 - val_acc: 0.8636
# Epoch 39/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3733 - acc: 0.9184 - val_loss: 0.4332 - val_acc: 0.8636
# Epoch 40/2000
# 49/49 [==============================] - 0s 89us/step - loss: 0.3723 - acc: 0.9184 - val_loss: 0.4326 - val_acc: 0.8636
# Epoch 41/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3713 - acc: 0.9184 - val_loss: 0.4320 - val_acc: 0.8636
# Epoch 42/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3704 - acc: 0.9184 - val_loss: 0.4313 - val_acc: 0.8636
# Epoch 43/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3694 - acc: 0.9184 - val_loss: 0.4308 - val_acc: 0.8636
# Epoch 44/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3686 - acc: 0.9184 - val_loss: 0.4303 - val_acc: 0.8636
# Epoch 45/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.3677 - acc: 0.9184 - val_loss: 0.4297 - val_acc: 0.8636
# Epoch 46/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3668 - acc: 0.9184 - val_loss: 0.4291 - val_acc: 0.8636
# Epoch 47/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3659 - acc: 0.9184 - val_loss: 0.4286 - val_acc: 0.8636
# Epoch 48/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.3650 - acc: 0.9184 - val_loss: 0.4280 - val_acc: 0.8636
# Epoch 49/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3641 - acc: 0.9184 - val_loss: 0.4275 - val_acc: 0.8636
# Epoch 50/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3633 - acc: 0.9184 - val_loss: 0.4270 - val_acc: 0.8636
# Epoch 51/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3624 - acc: 0.9184 - val_loss: 0.4264 - val_acc: 0.8636
# Epoch 52/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3615 - acc: 0.9184 - val_loss: 0.4259 - val_acc: 0.8636
# Epoch 53/2000
# 49/49 [==============================] - 0s 62us/step - loss: 0.3607 - acc: 0.9184 - val_loss: 0.4254 - val_acc: 0.8636
# Epoch 54/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3599 - acc: 0.9184 - val_loss: 0.4248 - val_acc: 0.8636
# Epoch 55/2000
# 49/49 [==============================] - 0s 122us/step - loss: 0.3590 - acc: 0.9184 - val_loss: 0.4243 - val_acc: 0.8636
# Epoch 56/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3581 - acc: 0.9184 - val_loss: 0.4238 - val_acc: 0.8636
# Epoch 57/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3572 - acc: 0.9184 - val_loss: 0.4233 - val_acc: 0.8636
# Epoch 58/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3564 - acc: 0.9184 - val_loss: 0.4227 - val_acc: 0.8636
# Epoch 59/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3555 - acc: 0.9184 - val_loss: 0.4222 - val_acc: 0.8636
# Epoch 60/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3546 - acc: 0.9184 - val_loss: 0.4217 - val_acc: 0.8636
# Epoch 61/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3537 - acc: 0.9184 - val_loss: 0.4212 - val_acc: 0.8636
# Epoch 62/2000
# 49/49 [==============================] - 0s 62us/step - loss: 0.3529 - acc: 0.9184 - val_loss: 0.4208 - val_acc: 0.8636
# Epoch 63/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.3521 - acc: 0.9388 - val_loss: 0.4203 - val_acc: 0.8636
# Epoch 64/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3512 - acc: 0.9388 - val_loss: 0.4198 - val_acc: 0.8636
# Epoch 65/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3504 - acc: 0.9388 - val_loss: 0.4193 - val_acc: 0.8636
# Epoch 66/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3496 - acc: 0.9388 - val_loss: 0.4188 - val_acc: 0.8636
# Epoch 67/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3487 - acc: 0.9388 - val_loss: 0.4183 - val_acc: 0.8636
# Epoch 68/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3479 - acc: 0.9388 - val_loss: 0.4178 - val_acc: 0.8636
# Epoch 69/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3470 - acc: 0.9388 - val_loss: 0.4174 - val_acc: 0.8636
# Epoch 70/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3463 - acc: 0.9388 - val_loss: 0.4169 - val_acc: 0.8636
# Epoch 71/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3454 - acc: 0.9388 - val_loss: 0.4165 - val_acc: 0.8636
# Epoch 72/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3447 - acc: 0.9388 - val_loss: 0.4160 - val_acc: 0.8636
# Epoch 73/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3439 - acc: 0.9388 - val_loss: 0.4156 - val_acc: 0.8636
# Epoch 74/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3431 - acc: 0.9388 - val_loss: 0.4151 - val_acc: 0.8636
# Epoch 75/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3424 - acc: 0.9388 - val_loss: 0.4147 - val_acc: 0.8636
# Epoch 76/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3416 - acc: 0.9388 - val_loss: 0.4143 - val_acc: 0.8636
# Epoch 77/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3409 - acc: 0.9592 - val_loss: 0.4139 - val_acc: 0.8636
# Epoch 78/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3401 - acc: 0.9592 - val_loss: 0.4134 - val_acc: 0.8636
# Epoch 79/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3394 - acc: 0.9592 - val_loss: 0.4130 - val_acc: 0.8636
# Epoch 80/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3386 - acc: 0.9592 - val_loss: 0.4126 - val_acc: 0.8636
# Epoch 81/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.3378 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 82/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.3371 - acc: 0.9592 - val_loss: 0.4118 - val_acc: 0.8636
# Epoch 83/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.3364 - acc: 0.9592 - val_loss: 0.4114 - val_acc: 0.8636
# Epoch 84/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.3356 - acc: 0.9592 - val_loss: 0.4110 - val_acc: 0.8636
# Epoch 85/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.3349 - acc: 0.9592 - val_loss: 0.4106 - val_acc: 0.8636
# Epoch 86/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.3342 - acc: 0.9592 - val_loss: 0.4101 - val_acc: 0.8636
# Epoch 87/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3335 - acc: 0.9592 - val_loss: 0.4097 - val_acc: 0.8636
# Epoch 88/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.3327 - acc: 0.9592 - val_loss: 0.4093 - val_acc: 0.8636
# Epoch 89/2000
# ...
# Epoch 1888/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1036 - acc: 0.9592 - val_loss: 0.4111 - val_acc: 0.8636
# Epoch 1889/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1036 - acc: 0.9592 - val_loss: 0.4111 - val_acc: 0.8636
# Epoch 1890/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1035 - acc: 0.9592 - val_loss: 0.4111 - val_acc: 0.8636
# Epoch 1891/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1035 - acc: 0.9592 - val_loss: 0.4112 - val_acc: 0.8636
# Epoch 1892/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1035 - acc: 0.9592 - val_loss: 0.4112 - val_acc: 0.8636
# Epoch 1893/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1035 - acc: 0.9592 - val_loss: 0.4114 - val_acc: 0.8636
# Epoch 1894/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1035 - acc: 0.9592 - val_loss: 0.4113 - val_acc: 0.8636
# Epoch 1895/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1034 - acc: 0.9592 - val_loss: 0.4113 - val_acc: 0.8636
# Epoch 1896/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1034 - acc: 0.9592 - val_loss: 0.4114 - val_acc: 0.8636
# Epoch 1897/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1034 - acc: 0.9592 - val_loss: 0.4113 - val_acc: 0.8636
# Epoch 1898/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1034 - acc: 0.9592 - val_loss: 0.4114 - val_acc: 0.8636
# Epoch 1899/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1034 - acc: 0.9592 - val_loss: 0.4115 - val_acc: 0.8636
# Epoch 1900/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1033 - acc: 0.9592 - val_loss: 0.4115 - val_acc: 0.8636
# Epoch 1901/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1033 - acc: 0.9592 - val_loss: 0.4116 - val_acc: 0.8636
# Epoch 1902/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1033 - acc: 0.9592 - val_loss: 0.4116 - val_acc: 0.8636
# Epoch 1903/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.1033 - acc: 0.9592 - val_loss: 0.4116 - val_acc: 0.8636
# Epoch 1904/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1033 - acc: 0.9592 - val_loss: 0.4117 - val_acc: 0.8636
# Epoch 1905/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1032 - acc: 0.9592 - val_loss: 0.4116 - val_acc: 0.8636
# Epoch 1906/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1032 - acc: 0.9592 - val_loss: 0.4117 - val_acc: 0.8636
# Epoch 1907/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1032 - acc: 0.9592 - val_loss: 0.4116 - val_acc: 0.8636
# Epoch 1908/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1032 - acc: 0.9592 - val_loss: 0.4117 - val_acc: 0.8636
# Epoch 1909/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1031 - acc: 0.9592 - val_loss: 0.4118 - val_acc: 0.8636
# Epoch 1910/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.1031 - acc: 0.9592 - val_loss: 0.4118 - val_acc: 0.8636
# Epoch 1911/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.1031 - acc: 0.9592 - val_loss: 0.4117 - val_acc: 0.8636
# Epoch 1912/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1031 - acc: 0.9592 - val_loss: 0.4118 - val_acc: 0.8636
# Epoch 1913/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1031 - acc: 0.9592 - val_loss: 0.4119 - val_acc: 0.8636
# Epoch 1914/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1030 - acc: 0.9592 - val_loss: 0.4119 - val_acc: 0.8636
# Epoch 1915/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1030 - acc: 0.9592 - val_loss: 0.4120 - val_acc: 0.8636
# Epoch 1916/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1030 - acc: 0.9592 - val_loss: 0.4121 - val_acc: 0.8636
# Epoch 1917/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1030 - acc: 0.9592 - val_loss: 0.4121 - val_acc: 0.8636
# Epoch 1918/2000
# 49/49 [==============================] - 0s 101us/step - loss: 0.1030 - acc: 0.9592 - val_loss: 0.4120 - val_acc: 0.8636
# Epoch 1919/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1029 - acc: 0.9592 - val_loss: 0.4121 - val_acc: 0.8636
# Epoch 1920/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.1029 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 1921/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1029 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 1922/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1029 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 1923/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1028 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 1924/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1028 - acc: 0.9592 - val_loss: 0.4123 - val_acc: 0.8636
# Epoch 1925/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1028 - acc: 0.9592 - val_loss: 0.4122 - val_acc: 0.8636
# Epoch 1926/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1028 - acc: 0.9592 - val_loss: 0.4123 - val_acc: 0.8636
# Epoch 1927/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1028 - acc: 0.9592 - val_loss: 0.4123 - val_acc: 0.8636
# Epoch 1928/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1027 - acc: 0.9592 - val_loss: 0.4124 - val_acc: 0.8636
# Epoch 1929/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1027 - acc: 0.9592 - val_loss: 0.4124 - val_acc: 0.8636
# Epoch 1930/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1027 - acc: 0.9592 - val_loss: 0.4124 - val_acc: 0.8636
# Epoch 1931/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1027 - acc: 0.9592 - val_loss: 0.4125 - val_acc: 0.8636
# Epoch 1932/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1027 - acc: 0.9592 - val_loss: 0.4126 - val_acc: 0.8636
# Epoch 1933/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1026 - acc: 0.9592 - val_loss: 0.4126 - val_acc: 0.8636
# Epoch 1934/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1026 - acc: 0.9592 - val_loss: 0.4126 - val_acc: 0.8636
# Epoch 1935/2000
# 49/49 [==============================] - 0s 104us/step - loss: 0.1026 - acc: 0.9592 - val_loss: 0.4127 - val_acc: 0.8636
# Epoch 1936/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1026 - acc: 0.9592 - val_loss: 0.4128 - val_acc: 0.8636
# Epoch 1937/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1025 - acc: 0.9592 - val_loss: 0.4128 - val_acc: 0.8636
# Epoch 1938/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1026 - acc: 0.9592 - val_loss: 0.4128 - val_acc: 0.8636
# Epoch 1939/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1025 - acc: 0.9592 - val_loss: 0.4128 - val_acc: 0.8636
# Epoch 1940/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1025 - acc: 0.9592 - val_loss: 0.4129 - val_acc: 0.8636
# Epoch 1941/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1025 - acc: 0.9592 - val_loss: 0.4128 - val_acc: 0.8636
# Epoch 1942/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.4129 - val_acc: 0.8636
# Epoch 1943/2000
# 49/49 [==============================] - 0s 62us/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.4129 - val_acc: 0.8636
# Epoch 1944/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.4130 - val_acc: 0.8636
# Epoch 1945/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.4131 - val_acc: 0.8636
# Epoch 1946/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.4131 - val_acc: 0.8636
# Epoch 1947/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4132 - val_acc: 0.8636
# Epoch 1948/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4132 - val_acc: 0.8636
# Epoch 1949/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4133 - val_acc: 0.8636
# Epoch 1950/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4134 - val_acc: 0.8636
# Epoch 1951/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4135 - val_acc: 0.8636
# Epoch 1952/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1023 - acc: 0.9592 - val_loss: 0.4134 - val_acc: 0.8636
# Epoch 1953/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1022 - acc: 0.9592 - val_loss: 0.4134 - val_acc: 0.8636
# Epoch 1954/2000
# 49/49 [==============================] - 0s 62us/step - loss: 0.1022 - acc: 0.9592 - val_loss: 0.4135 - val_acc: 0.8636
# Epoch 1955/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1022 - acc: 0.9592 - val_loss: 0.4135 - val_acc: 0.8636
# Epoch 1956/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1022 - acc: 0.9592 - val_loss: 0.4136 - val_acc: 0.8636
# Epoch 1957/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4136 - val_acc: 0.8636
# Epoch 1958/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4137 - val_acc: 0.8636
# Epoch 1959/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4138 - val_acc: 0.8636
# Epoch 1960/2000
# 49/49 [==============================] - 0s 80us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4139 - val_acc: 0.8636
# Epoch 1961/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4140 - val_acc: 0.8636
# Epoch 1962/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1021 - acc: 0.9592 - val_loss: 0.4141 - val_acc: 0.8636
# Epoch 1963/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4141 - val_acc: 0.8636
# Epoch 1964/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4142 - val_acc: 0.8636
# Epoch 1965/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4143 - val_acc: 0.8636
# Epoch 1966/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4143 - val_acc: 0.8636
# Epoch 1967/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 1968/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4143 - val_acc: 0.8636
# Epoch 1969/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1019 - acc: 0.9592 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 1970/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1019 - acc: 0.9592 - val_loss: 0.4144 - val_acc: 0.8636
# Epoch 1971/2000
# 49/49 [==============================] - 0s 142us/step - loss: 0.1019 - acc: 0.9592 - val_loss: 0.4145 - val_acc: 0.8636
# Epoch 1972/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1019 - acc: 0.9592 - val_loss: 0.4145 - val_acc: 0.8636
# Epoch 1973/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1018 - acc: 0.9592 - val_loss: 0.4145 - val_acc: 0.8636
# Epoch 1974/2000
# 49/49 [==============================] - 0s 103us/step - loss: 0.1018 - acc: 0.9592 - val_loss: 0.4145 - val_acc: 0.8636
# Epoch 1975/2000
# 49/49 [==============================] - 0s 40us/step - loss: 0.1018 - acc: 0.9592 - val_loss: 0.4145 - val_acc: 0.8636
# Epoch 1976/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1018 - acc: 0.9592 - val_loss: 0.4146 - val_acc: 0.8636
# Epoch 1977/2000
# 49/49 [==============================] - 0s 122us/step - loss: 0.1018 - acc: 0.9592 - val_loss: 0.4146 - val_acc: 0.8636
# Epoch 1978/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4147 - val_acc: 0.8636
# Epoch 1979/2000
# 49/49 [==============================] - 0s 82us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4147 - val_acc: 0.8636
# Epoch 1980/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4148 - val_acc: 0.8636
# Epoch 1981/2000
# 49/49 [==============================] - 0s 60us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4148 - val_acc: 0.8636
# Epoch 1982/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4149 - val_acc: 0.8636
# Epoch 1983/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.1016 - acc: 0.9592 - val_loss: 0.4149 - val_acc: 0.8636
# Epoch 1984/2000
# 49/49 [==============================] - 0s 41us/step - loss: 0.1017 - acc: 0.9592 - val_loss: 0.4149 - val_acc: 0.8636
# Epoch 1985/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1016 - acc: 0.9592 - val_loss: 0.4150 - val_acc: 0.8636
# Epoch 1986/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1016 - acc: 0.9592 - val_loss: 0.4150 - val_acc: 0.8636
# Epoch 1987/2000
# 49/49 [==============================] - 0s 143us/step - loss: 0.1016 - acc: 0.9592 - val_loss: 0.4151 - val_acc: 0.8636
# Epoch 1988/2000
# 49/49 [==============================] - 0s 61us/step - loss: 0.1016 - acc: 0.9592 - val_loss: 0.4150 - val_acc: 0.8636
# Epoch 1989/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1015 - acc: 0.9592 - val_loss: 0.4151 - val_acc: 0.8636
# Epoch 1990/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1015 - acc: 0.9592 - val_loss: 0.4152 - val_acc: 0.8636
# Epoch 1991/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1015 - acc: 0.9592 - val_loss: 0.4152 - val_acc: 0.8636
# Epoch 1992/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1015 - acc: 0.9592 - val_loss: 0.4153 - val_acc: 0.8636
# Epoch 1993/2000
# 49/49 [==============================] - 0s 126us/step - loss: 0.1014 - acc: 0.9592 - val_loss: 0.4153 - val_acc: 0.8636
# Epoch 1994/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1014 - acc: 0.9592 - val_loss: 0.4153 - val_acc: 0.8636
# Epoch 1995/2000
# 49/49 [==============================] - 0s 163us/step - loss: 0.1014 - acc: 0.9592 - val_loss: 0.4154 - val_acc: 0.8636
# Epoch 1996/2000
# 49/49 [==============================] - 0s 163us/step - loss: 0.1014 - acc: 0.9592 - val_loss: 0.4155 - val_acc: 0.8636
# Epoch 1997/2000
# 49/49 [==============================] - 0s 81us/step - loss: 0.1014 - acc: 0.9592 - val_loss: 0.4155 - val_acc: 0.8636
# Epoch 1998/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1013 - acc: 0.9592 - val_loss: 0.4156 - val_acc: 0.8636
# Epoch 1999/2000
# 49/49 [==============================] - 0s 102us/step - loss: 0.1013 - acc: 0.9592 - val_loss: 0.4155 - val_acc: 0.8636
# Epoch 2000/2000
# 49/49 [==============================] - 0s 122us/step - loss: 0.1013 - acc: 0.9592 - val_loss: 0.4156 - val_acc: 0.8636
#
#
#
# Accuracy Score for Nerual Network is 86.364
#
# Nerual Network roc-auc is 0.865
#
#
#
# Nerual Network Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89        17
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.82        22
#    macro avg       0.75      0.67      0.69        22
# weighted avg       0.80      0.82      0.80        22
#
# LogisticRegression: 0.916071 (0.093831)
# RandomForest: 0.844643 (0.135067)
# DecisionTree: 0.844643 (0.135067)
